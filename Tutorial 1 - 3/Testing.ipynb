# %%
print('plss')
# Out:
# plss

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %%
#import libs
import matplotlib.pyplot as plt

#initialize
fig = plt.figure() #creates new fig
ax = plt.subplot() #add an axes to current figure

#boxplot data
Branch_1 = [50,70,60,120,45,53,95,180]


#plot data as boxplot
ax.boxplot([Branch_1], labels=['Branch 1'])
ax.set_xlabel("Branches") # add label for x axis
ax.set_ylabel("Unit price($)") # add label for y axis
plt.show()

# %%
# import libraries
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.boxplot.html
import matplotlib.pyplot as plt

# initialization
fig = plt.figure() # create new figure
ax = plt.subplot() # add an axes to current figure

# boxplot data
Branch_1 = [50, 70, 60, 120, 45, 53, 95, 180]
Branch_2 = [124, 83, 135, 124, 122, 113, 100, 142, 110, 107]
Branch_3 = [115, 86, 84, 80, 124, 40, 78, 198, 52, 81]

# plot data as boxplot
ax.boxplot([Branch_1, Branch_2, Branch_3], labels=['Branch 1', 'Branch 2', 'Branch 3'])
ax.set_xlabel("Branches") # add label for x axis
ax.set_ylabel("Unit price($)") # add label for y axis
plt.show()

# %%
# import libraries
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html
import matplotlib.pyplot as plt

# initialization
fig = plt.figure() # create new figure
ax = plt.subplot() # add an axes to current figure

# histogram data
price_of_sold_items = [111.875347, 55.66728581, 71.08146353, 113.13083934, 114.09990563, 78.64788756, 80.05848748, 113.51723315, 97.03476129, 75.70515939, 98.91572427, 116.44081594, 121.20025616, 108.61252504, 115.74171863, 86.91079634, 60.40371063, 108.72678253, 95.61269395, 60.47926825, 138.83567334, 126.24428234, 98.19814224, 77.17727311, 67.81920375, 60.11092133, 102.99010443, 76.80342109, 88.94551651, 81.90125526, 134.89126979, 97.09425656, 103.5323964, 123.38747963, 68.9606892, 113.35229245, 103.70553551, 68.95012599, 66.72576283, 93.80937187, 112.39484486, 119.33408967, 51.19870471, 102.33804355, 109.86230632, 104.35084208, 85.82973656, 56.33195302, 101.54502826, 77.43347455, 75.7075575, 49.4717575, 91.20220019, 87.02258197, 103.0139261, 130.01272565, 85.69321849, 86.45789384, 51.99333966, 54.24093256, 95.69515467, 68.89899967, 127.23060963, 50.50058379, 95.68144662, 95.72903494, 68.48824698, 80.7560343, 88.13659114, 69.92246465, 102.64265764, 133.81661872, 131.59787921, 105.95529561, 68.11625805, 113.90777092, 85.0609364, 72.75408163, 110.62530375, 119.60652971, 63.41505009, 52.44736665, 101.77706899, 79.48263694, 112.40858362, 79.54703057, 58.17448803, 51.2195867, 82.19478456, 46.76263358, 53.88010361, 126.8328212, 100.71380416, 58.87590025, 115.67418875, 83.02599466, 99.08067453, 100.23833469, 54.39699105, 88.94974289, 91.04240909, 57.1409587, 100.15503029, 75.44611043, 118.92956224, 73.84189864, 110.73359892, 92.17971047, 78.0558932, 91.18219983, 71.54766751, 126.17311436, 93.94040682, 102.52564541, 88.10372701, 105.0257804, 100.64042965, 112.11446398, 82.25844123, 95.06842488, 64.31520517, 112.26527165, 81.96943625, 85.97352201, 106.66365891, 112.76387079, 81.57971529, 60.33946174, 83.7044522, 68.29615894, 82.08411577, 84.63078051, 101.02768711, 99.05904779, 49.86291813, 85.84494375, 112.16625992, 75.06755111, 50.65319786, 46.68414086, 66.75912635, 84.73128246, 69.78215661, 109.14849338, 118.5299049, 89.53632387, 108.74591372, 76.89675378, 88.26946145, 87.85792133, 93.05591814, 92.36402736, 79.402443, 120.07927064, 94.98104997, 106.99332727, 90.02287151, 83.1963865, 73.90248601, 68.78405462, 94.99394894, 76.77158668, 70.67129294, 90.98489899, 92.67342368, 96.87946299, 64.35119308, 93.30357921, 86.93392166, 66.43443151, 121.14832114, 55.02507342, 96.32205241, 100.76371816, 61.20028525, 58.90858172, 104.87985326, 46.03109043, 87.39066976, 95.6274963, 106.64955118, 88.22838094, 50.31681381, 76.64460532, 67.30470243, 75.41585454, 133.283633, 98.52412887, 132.77075427, 83.45179207, 74.06327122, 126.44231534, 111.62760969, 109.53063629, 81.30259654, 75.50026721, 56.44376788, 93.68642395, 47.55527209, 91.74002323, 89.19747632, 74.98648771, 91.80259112, 108.20152308, 72.399899, 53.84861656, 100.72664532, 96.90560139, 94.74603502, 113.7702083, 77.74334801, 133.67280274, 102.50977869, 75.96897011, 90.35362091, 73.35141273, 96.75857964, 106.60796882, 92.80136915, 88.80661715, 70.10160162, 114.0972694, 70.40125991, 49.24416584, 129.20285991, 137.11358621, 75.00023484, 92.96163373, 55.12015222, 71.01279885, 128.18764088, 93.10076858, 86.97839622, 117.92507165, 109.24826406, 95.96924629, 125.95746486, 118.78553906, 54.11335776, 134.22166749, 57.81223185, 75.73323142, 87.14317127, 50.1613787, 131.04129927, 79.43124273, 52.7244543, 83.62836714, 108.8232441, 98.42822401, 88.85596811, 132.44036759, 86.89497199, 103.75642243, 72.76807353, 68.62012429, 87.17079444, 117.85386209, 63.46080212, 94.50747408, 92.22673339, 101.23046349, 95.34010415, 114.35059216, 72.27421912, 56.78769108, 82.76508355, 94.31241338, 69.30620911, 128.06274514, 97.37805132, 67.25731545, 91.18707706, 110.66226476, 90.1848328, 122.75194563, 77.98707918, 99.60080017, 48.63230369, 104.6474218, 137.45465379, 127.28027133, 90.21805626, 122.67595777, 51.7470631, 106.07499628, 110.66868928, 75.54425063, 116.57448343, 82.08620791, 112.78165067, 106.85989147, 87.6099609, 72.56510495, 72.06034489, 53.94909866, 71.59000398, 103.93510449, 42.36492335, 77.00305078]

# plot data
ax.hist(price_of_sold_items, bins=[40,60,80,100,120,140], edgecolor='white', linewidth=15)
ax.set_xlabel("Unit Price ($)") # add label for x axis
ax.set_ylabel("Count of items sold") # add label for y axis
plt.show()

# %%
# import libraries
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html
import matplotlib.pyplot as plt

# initialization
fig = plt.figure() # create new figure
ax = plt.subplot() # add an axes to current figure

# scatter plot data
unit_price = range(40, 140)
items_sold = [193, 282, 141, 155, 148, 365, 205, 249, 324, 271, 338, 209, 392, 224, 295, 279, 226, 293, 368, 287, 350, 310, 379, 309, 320, 401, 233, 466, 450, 332, 322, 331, 431, 489, 407, 469, 399, 447, 352, 508, 598, 432, 430, 618, 497, 432, 355, 612, 420, 526, 550, 472, 520, 582, 450, 534, 544, 555, 575, 533, 542, 623, 546, 430, 465, 518, 469, 404, 444, 417, 471, 497, 509, 597, 517, 372, 515, 378, 493, 289, 479, 417, 410, 427, 400, 219, 314, 417, 425, 357, 352, 262, 313, 382, 318, 339, 210, 395, 190, 204]

# plot data
ax.scatter(x=unit_price, y=items_sold, marker="D")
ax.set_xlim(0, 140)
ax.set_xlabel("Unit Price ($)") # add label for x axis
ax.set_ylabel("Items sold") # add label for y axis
plt.show()
